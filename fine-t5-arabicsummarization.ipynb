# %%
import pandas as pd 
import numpy as np
import seaborn as sns
from pylab import rcParams
import matplotlib.pyplot as plt
from matplotlib import rc

# %matplotlib inline
# %config InlineBackend.figure_format='retina'
sns.set(style='whitegrid', palette='muted', font_scale=1.2)
rcParams['figure.figsize'] = 16, 10

from transformers import AutoTokenizer, AutoModelForSeq2SeqLM
import torch
from torch import nn,optim
from torch.utils.data import Dataset, DataLoader
from torchmetrics.functional import f1
import pytorch_lightning as pl
from pytorch_lightning.callbacks.early_stopping import EarlyStopping
from pytorch_lightning.loggers import TensorBoardLogger
from sklearn.model_selection import train_test_split

import joblib

# %%
path_input = '../input/headlines/summary.csv'
df = pd.read_csv(path_input)
df['summary'] = df['summary'].replace(r'\n', '', regex = True)
df.head()
# Out:
#                                                 text  \
# 0  و هو يعتبر متحف جديد العهد ، يقدم مجموعة من ال...
# 1  يعتبر فيلاجيو مول من أهم المجمعات التجارية و أ...
# 2  هو المنطقة البحرية الممتدة على مجموعة كيلومترا...
# 3  يعتبر هذا المنتجع من أجمل الأماكن الساحلية الم...
# 4  و هو منتجع مطل على البحر ، و يحوي العديد من أم...
#
#                      summary
# 0  المتحف العربي للفن الحديث
# 1                فيلاجيو مول
# 2              كورنيش الدوحة
# 3           منتجع شاطئ سيلين
# 4              منتجع الغارية

# %%
df = df[:100_000]
len(df)
# Out:
# 100000

# %%
train, val = train_test_split(df, test_size=0.1, random_state=42)

train.to_csv("train.csv",index=False)
val.to_csv("val.csv",index=False)

# %%
# tokenizer = AutoTokenizer.from_pretrained("csebuetnlp/mT5_multilingual_XLSum")

# text_token_counts = train['text'].apply(lambda x : len(tokenizer.encode(x)))
# summary_token_counts = train['summary'].apply(lambda x : len(tokenizer.encode(x)))

# fig, (ax1, ax2) = plt.subplots(1, 2)
# sns.boxplot(text_token_counts, ax=ax1)
# ax1.set_title('full text token counts')
# sns.boxplot(summary_token_counts, ax=ax2)
# ax2.set_title('summary text token counts')

# %%
class SummaryDataset(Dataset):
    def __init__(
        self,
        data,
        text_max_token_len,
        summary_max_token_len
    ):
        self.tokenizer = AutoTokenizer.from_pretrained("csebuetnlp/mT5_multilingual_XLSum")
        self.data = data
        self.text_max_token_len = text_max_token_len
        self.summary_max_token_len = summary_max_token_len
    
    def __len__(self):
        return len(self.data)

    def __getitem__(self, index: int):
        data_row = self.data.iloc[index]

        text = data_row['text']

        text_encoding = self.tokenizer(
            text,
            max_length=self.text_max_token_len,
            padding='max_length',
            truncation=True,
            return_attention_mask=True,
            add_special_tokens=True,
            return_tensors='pt'
        )

        summary_encoding = self.tokenizer(
            data_row['summary'],
            max_length=self.summary_max_token_len,
            padding='max_length',
            truncation=True,
            return_attention_mask=True,
            add_special_tokens=True,
            return_tensors='pt'
        )
        
        labels = summary_encoding['input_ids']
        labels[labels == self.tokenizer.pad_token_id] = -100
        
        return dict(
            input_ids=text_encoding['input_ids'].flatten(),
            attention_mask=text_encoding['attention_mask'].flatten(),
            labels=labels.flatten(),
            decoder_attention_mask=summary_encoding['attention_mask'].flatten()
        )

# %%
class SummaryDataModule(pl.LightningDataModule):
    def __init__(self,train_path,val_path,batch_size=8, text_max_token_len = 400, summary_max_token_len = 17):
        super().__init__()
        self.train_path,self.val_path= train_path,val_path
        self.batch_size = batch_size
        self.text_max_token_len = text_max_token_len
        self.summary_max_token_len = summary_max_token_len
    
    def setup(self,stage=None):
        train = pd.read_csv(self.train_path)
        val = pd.read_csv(self.val_path)
        self.train_dataset = SummaryDataset(data=train,
                                            text_max_token_len=self.text_max_token_len,
                                            summary_max_token_len=self.summary_max_token_len)
        self.val_dataset = SummaryDataset(data=val,
                                          text_max_token_len=self.text_max_token_len,
                                          summary_max_token_len=self.summary_max_token_len)
    
    def train_dataloader(self):
        return DataLoader(self.train_dataset,batch_size=self.batch_size,shuffle=True)
    
    def val_dataloader(self):
        return DataLoader(self.val_dataset,batch_size=self.batch_size,shuffle=False)

# %%
class T5SumModel(pl.LightningModule):
    def __init__(self, lr=0.0001):
        super().__init__()
        self.lr = lr
        self.model = AutoModelForSeq2SeqLM.from_pretrained("csebuetnlp/mT5_multilingual_XLSum")
    
    def forward(self, input_ids, attention_mask, decoder_attention_mask, labels=None):
        output = self.model(
            input_ids,
            attention_mask=attention_mask,
            labels=labels,
            decoder_attention_mask=decoder_attention_mask
        )
        return output.loss, output.logits
    
    def configure_optimizers(self):
        return optim.AdamW(self.parameters(), lr=self.lr)
    
    def training_step(self, batch, batch_size):
        input_ids = batch['input_ids']
        attention_mask = batch['attention_mask']
        labels = batch['labels']
        decoder_attention_mask = batch['decoder_attention_mask']

        loss, outputs = self(
            input_ids=input_ids,
            attention_mask=attention_mask,
            decoder_attention_mask=decoder_attention_mask,
            labels=labels
        )

        self.log("train_loss", loss, prog_bar=True, logger=True)
        return loss
    
    def validation_step(self, batch, batch_size):
        input_ids = batch['input_ids']
        attention_mask = batch['attention_mask']
        labels = batch['labels']
        decoder_attention_mask = batch['decoder_attention_mask']

        loss, outputs = self(
            input_ids=input_ids,
            attention_mask=attention_mask,
            decoder_attention_mask=decoder_attention_mask,
            labels=labels
        )

        self.log("val_loss", loss, prog_bar=True, logger=True)
        return loss

# %%
dm = SummaryDataModule(train_path="./train.csv",
                val_path = "./val.csv",
                batch_size=1)

# First Time only
trained_model = T5SumModel() 

# Load checkpoint
trained_model = T5SumModel.load_from_checkpoint(
    '../input/fine-t5-arabicsummarization/lightning_logs/version_0/checkpoints/epoch=0-step=89999.ckpt'
)

# Traing
# trainer = pl.Trainer(gpus=-1,
#                      max_epochs=1,
#                      default_root_dir='.',
#                      callbacks=[EarlyStopping(monitor="val_loss")])
# trainer.fit(trained_model,dm)
# Out:
# Downloading:   0%|          | 0.00/730 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/2.17G [00:00<?, ?B/s]

# %%
tokenizer = AutoTokenizer.from_pretrained("csebuetnlp/mT5_multilingual_XLSum")
model = AutoModelForSeq2SeqLM.from_pretrained("csebuetnlp/mT5_multilingual_XLSum")

trained_model.freeze()

def summarizeText(text, mymodel):
    text_encoding = tokenizer(
        text,
        max_length=1000,
        padding='max_length',
        truncation=True,
        return_attention_mask=True,
        add_special_tokens=True,
        return_tensors='pt'
    )
    generated_ids = mymodel.generate(
        input_ids=text_encoding['input_ids'],
        attention_mask=text_encoding['attention_mask'],
        max_length=150,
        num_beams=2,
        repetition_penalty=2.5,
        length_penalty=1.0,
        early_stopping=True
    )

    preds = [
            tokenizer.decode(gen_id, skip_special_tokens=True, clean_up_tokenization_spaces=True)
            for gen_id in generated_ids
    ]
    return "".join(preds)
# Out:
# Downloading:   0%|          | 0.00/375 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/4.11M [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/65.0 [00:00<?, ?B/s]

# %%
test = val.sample(10)
for i in range(len(test)):
    sample_row = test.iloc[i]
    text = sample_row['text']
    print('Text : ', text)
    print('\n')
    print('Summary (Ground truth) : ',sample_row['summary'])
    print('\n')
    summary_without_tuning = summarizeText(text, model)
    print("Summary before tuning", summary_without_tuning)
    print('\n')
    summary_with_tuning = summarizeText(text, trained_model.model)
    print("Summary after tuning", summary_with_tuning)
    print('\n')
    print('-------------------------------------------------------------------------------------------------')
# Out:
# Text :  من أركان الإيمان الإيمان بالله و رسله و منهم سيدنا محمد صلى الله عليه و سلم ؛ فقد أرسله الله للإنس و الجن يحمل رسالة الهداية ، و المؤمن يحمل هذا الاعتقاد في قلبه ، و يظهر في سلوكه ، فللنبي صلى الله عليه و سلم على أمته حقوق في طاعته ، و اتباعه ، و احترام مقامه ، و توقيره بينها الله في كتابه و النبي صلى الله عليه و سلم في سنته ، و فيما يأتي سنبين هذه الحقوق مع أدلتها .
#
#
#
# Summary (Ground truth) :  نبوة محمد صلى الله عليه و سلم
#
#
# Summary before tuning في هذا الوقت من كل عام، يؤدي الإيمان بالله و رسله إلى توحيد الأمن والنبي صلى الله عليه و سلم.
#
#
# Summary after tuning الإيمان بالله
#
#
# -------------------------------------------------------------------------------------------------
# Text :  تعد هذه المرحلة هي المرحلة النهائية لفصل مشتقات النفط عن بعضها البعض ، و تتم باستخدام العمليات الفيزيائية ، أو العمليات الكيميائية ، مثل : استخدام محلول الصودا الكاوية ؛ لتنقية البوتاجاز و البنزين من كبريتيد الهيدروجين ، أو استخدام و حمض الكبريتيك المركز لتنقية الكيروسين من المواد الكبريتية و العطرية التي تسبب تصاعد الدخان الأسود ، و وقود النفاثات و غيره ، كذلك يستخدم غاز الهيدروجين في إزالة العديد من الشوائب ، أو استخدام سائل لامتصاص كبريتيد الهيدوجين إذا كانت نسبته كبيرة ؛ لأنه يساعد على تآكل الآلات و المعدات .
#
#
#
# Summary (Ground truth) :  التنقية أو المعالجة
#
#
# Summary before tuning يشهد العالم في الوقت الحالي مرحلة من العمليات الفيزيائية و الكيميائية التي تهدف إلى إزالة النفط عن بعضها البعض.
#
#
# Summary after tuning فصل مشتقات النفط
#
#
# -------------------------------------------------------------------------------------------------
# Text :  ضغط الأذن الوسطى هو عبارة عن التهاب يصيب الأغشية المخاطية الموجودة في الأذن الوسطى نتيجة وجود فرق في ضغط الأذن الوسطى بسبب تغير الضغط الجوي مقارنة مع الضغط المحيطي الناتج من انسداد في قناة الأذن ، و عادة ما يحصل ضغط الأذن الوسطى عند النزول من منطقة مرتفعة إلى منطقة منخفضة ذات ضغط هوائي أعلى ، مما يؤثر في النفير ( القناة الواصلة بين الأذن و الأنف ) و الأعصاب الموجودة في الأذن .
#
#
#
# Summary (Ground truth) :  ضغط الأذن الوسطى
#
#
# Summary before tuning ضغط الأذن الوسطى هو عبارة عن التهاب يصيب الأغشية المخاطية الموجودة في الأأذن.
#
#
# Summary after tuning ضغط الأذن الوسطى
#
#
# -------------------------------------------------------------------------------------------------
# Text :  تعيش أنواع أخرى من البط معظم حياتها على اليابسة ، و تحديدا في المناطق التي تكثر فيها محاصيل الحبوب و البقول التي تفضل التغذية عليها .
#
#
#
# Summary (Ground truth) :  صيد البط في المحاصيل
#
#
# Summary before tuning هناك أنواع من البط التي تعيش على اليابسة.
#
#
# Summary after tuning حياة البط
#
#
# -------------------------------------------------------------------------------------------------
# Text :  إن الحصول على بشرة خالية من العيوب و فاتحة اللون حلم للجميع ، لكن العوامل التي تتعرض لها البشرة ، مثل : التلوث ، و الأشعة فوق البفنسجية ، و النظام الغذائي السيئ ، و التوتر ، كلها عوامل تؤثر على البشرة ، وتدمر الجلد ، و يمكن أن نلجأ لمستحضرات العناية بالبشرة و تفتيحها المنتشرة بالأسواق لكنها تحتوي على مواد كيميائية ضارة تسبب المزيد من الضرر للبشرة ، لذلك تكون المكونات الطبيعية هي الحل الآمن و المناسب لتفتيح البشرة ، وجعلها أكثر إشراقا و توازنا .
#
#
#
# Summary (Ground truth) :  تفتيح لون البشرة
#
#
# Summary before tuning يمكن أن تكون المكونات الطبيعية هي الحل الآمن لتفتيح البشرة وجعلها أكثر إشراقا و توازنا.
#
#
# Summary after tuning تفتيح البشرة
#
#
# -------------------------------------------------------------------------------------------------
# Text :  ظن العلماء أن كتلة الذرة تساوي كتلة البروتونات التي توجد في نواتها ، و لكن عندما تم قياسها باستعمال مطياف الكتلة اكتشفوا أن مقدار كتلة النواة للعنصر تصل أحيانا لضعف حجم الكتلة المتوقعة للنواة ، لذلك افترضوا وجود جسيمات ذات شحنة متعادلة داخل النواة مع عدد من البروتونات التي تم اكتشافها علميا عام 1932م حيث قام العالم شادويك بقذف دقائق من الألفا على شريحة من البيريليوم مما أدى إلى ظهور أشعة على أجسام غير مشحونة ، إلا أن كتلتها تعادل كتلة البروتونات ، و أطلق عليها اسم النيوترونات .
#
#
#
# Summary (Ground truth) :  كيفية اكتشاف النيوترونات
#
#
# Summary before tuning اكتشف علماء في بريطانيا النقاب عن كتلة الذرة التي توجد في نواتها ، وذلك بعد أن أعلنوا وجود جسيمات ذات شحنة متعادلة مع البروتونات.
#
#
# Summary after tuning كيفية حساب الذرة
#
#
# -------------------------------------------------------------------------------------------------
# Text :  تم إنشاء هذه اللغة من قبل الفيلسوف كاي أوغدن ، من أجل استخدامها كإحدى اللغات الدولية المساعدة ، بالإضافة إلى استعمالها كعامل مساعد في تدريس اللغة الإنجليزية كلغة رسمية و دولية ثانية ، و تقوم هذه اللغة على التحكم في إنشاء و تبسيط اللغة ، و تستعمل في العديد من الدول كلغة رسمية كالولايات المتحدة الأمريكية و غيرها الكثير من دول العالم .
#
#
#
# Summary (Ground truth) :  اللغة الإنجليزية
#
#
# Summary before tuning هذه اللغة الإنجليزية تستخدم في العديد من الدول العالمية لاستخدامها ككلغة رسمية و دولية ثانية.
#
#
# Summary after tuning اللغة الفرنسية
#
#
# -------------------------------------------------------------------------------------------------
# Text :  ولى أمير المؤمنين عمر بن الخطاب سلمان الفارسي على بلاد فارس ، فدخلها وصلى بالناس فيها يوم الجمعة ، أما وفاته فكانت في عهد عثمان بن عفان ، و قد تولى عثمان - رضي الله عنه - دفنه و الصلاة عليه و تجهيزه ، و يقع مقامه في مدينة المدائن على بعد كيلومترين من نطاق كسرى ، توفي عام 644 م .
#
#
#
# Summary (Ground truth) :  وفاة سلمان الفارسي
#
#
# Summary before tuning كانت بلاد فارس عاصمة ملكية السعودية ، فقد وصلت إلى البلاد في عام 644 م.
#
#
# Summary after tuning وفاة سلمان الفارسي
#
#
# -------------------------------------------------------------------------------------------------
# Text :  يمكن تنزيل أية مرفقات موجودة ضمن البريد الإلكتروني ياهو ، و من ضمنها ملفات الفيديو من خلال القيام بالخطوات التالية :
#
#
#
# Summary (Ground truth) :  تنزيل الفيديوهات من البريد الإلكتروني ياهو
#
#
# Summary before tuning ياهو ، عملاق البريد الإلكتروني الالكتروني، يمكنه تنزيل مرفقات الفيديو من خلال تطبيقه.
#
#
# Summary after tuning كيفية تنزيل ملفات الفيديو
#
#
# -------------------------------------------------------------------------------------------------
# Text :  يستخدم زيت الزيتون لأغراض عدة ، إذ يهدف الناس إلى تحقيق أقصى منفعة ممكنة من خصائصه الطبيعية و فوائده الكبيرة التي تعود على الصحة الفسيولوجية ، والدماغية ، و العضلية ، حيث يعد هذا الزيت من أهم أنواع الزيوت الطبيعية التي يتم الحصول عليها من شجرة الزيتون المباركة ذات الانتشار الواسع في العديد من المناطق حول العالم ، و على رأسها المناطق الواقعة ضمن نطاق حوض البحر الأبيض المتوسط . يمتاز زيت الزيتون بتركيبته الطبيعية المشبعة بالعناصر الأساسية للجسم ، بما في ذلك كل من الفيتامينات ، و الأحماض ، و المعادن ، و الأملاح ، ومضادات الأكسدة ، مما يجعل منه علاجا فعالا للمشاكل الصحية المختلفة ، التي يؤثر بعضها سلبا في المظهر الجمالي الخارجي للجسم مثل السمنة التي تؤدي إلى تراكم الدهون حول منطقة البطن و يرافقها بروز غير مرغوب للكرش ، و نظرا لتأثيرها السيء في الجسم سنذكر أبرز فوائد زيت الزيتون للتخلص من السمنة ، و تحديدا في منطقة البطن .
#
#
#
# Summary (Ground truth) :  زيت الزيتون
#
#
# Summary before tuning يعتبر زيت الزيتون من أهم الأطعمة الطبيعية في العالم ، إذ ينبغي الناس إلى تحقيق أقصى منفعة ممكنة من خصائصه طبيعية و فوائده الكبيرة التي تعود على الصحة الفسيولوجية, والدماغية.
#
#
# Summary after tuning زيت الزيتون
#
#
# -------------------------------------------------------------------------------------------------
